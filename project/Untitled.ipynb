# %%
# !pip install tensorflow tensorflow-hub

# %%
import tensorflow as tf
import tensorflow_hub as hub

print(tf.__version__)
print("TF Hub OK")

# %%
model = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")
print("USE model loaded")

# %%
import os
os.environ["TFHUB_CACHE_DIR"] = os.path.expanduser("~/tfhub_cache")
print(os.environ["TFHUB_CACHE_DIR"])
# Out:
# C:\Users\29846/tfhub_cache

# %%
import tensorflow as tf
import tensorflow_hub as hub

print(tf.__version__)
print("TF Hub OK")
# Out:
# E:\Anaconda\envs\tf_env\lib\site-packages\tensorflow_hub\__init__.py:61: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version
# WARNING:tensorflow:From E:\Anaconda\envs\tf_env\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 2.20.0
# TF Hub OK

# %%
import tensorflow_hub as hub
model = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")
print("USE model loaded")
# Out:
# WARNING:tensorflow:From E:\Anaconda\envs\tf_env\lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From E:\Anaconda\envs\tf_env\lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
